# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("F:/ML/Zenrays/AI_ML_Feb25_Kormangla/hands on/exercise_cleanData/logic_1.csv")
df
# Out:
#           Case ID    First Name   Last Name Account Type
# 0         Case1-1          Jack      Dorsey      Federal
# 1         Case2-1          Dave      Cooper        State
# 2         Case3-1         Mudit     AGRAWAL   Commercial
# 3         Case1-2         Larry      Begley      Federal
# 4         Case2-2           Jim    Schraith        State
# 5         Case3-2           Tig      Krekel   Commercial
# 6         Case1-3         Maria      Cirino      Federal
# 7         Case2-3         Blair      Garrou        State
# 8         Case3-3       Stephen      Brooks   Commercial
# 9         Case1-4          Liam     Donohue      Federal
# 10        Case2-4           Ned        Hill        State
# 11        Case3-4        Victor      Caruso   Commercial
# 12        Case1-5          Greg      Dracon      Federal
# 13        Case2-5           Dan     Watkins        State
# 14        Case3-5  C. Alexander      Harman   Commercial
# ...

# %%
#print the rows with null values
df[df.isnull().any(axis=1)]
# Out:
#           Case ID First Name Last Name Account Type
# 209      Case3-70        NaN       NaN   Commercial
# 413     Case3-138        NaN       NaN   Commercial
# 1062    Case1-355        NaN       NaN      Federal
# 1270    Case2-424        NaN       NaN        State
# 1742    Case3-581        NaN       NaN   Commercial
# 1828    Case2-610        NaN      Bono        State
# 2737    Case2-913        NaN       NaN        State
# 3187   Case2-1063        NaN       NaN        State
# 4939   Case2-1647        NaN       NaN        State
# 5191   Case2-1731        NaN       NaN        State
# 5292   Case1-1765        NaN       NaN      Federal
# 5700   Case1-1901        NaN       NaN      Federal
# 6067   Case2-2023        NaN       NaN        State
# 6088   Case2-2030        NaN       NaN        State
# 6890   Case3-2297        NaN       NaN   Commercial
# 6902   Case3-2301        NaN       NaN   Commercial
# 7436   Case3-2479        NaN       NaN   Commercial
# ...

# %%
df2=df

# %%
i = 1
for row in df2.index.tolist():
    if pd.isna(df2.loc[row,"Case ID"]) == False and pd.isna(df2.loc[row,"First Name"]) == True:
        df2.loc[row,"First Name"] = "Unknown %s" % i
        i += 1
        print (df2.loc[row])
# Out:
# Case ID           Case3-70
# First Name       Unknown 1
# Last Name              NaN
# Account Type    Commercial
# Name: 209, dtype: object
# Case ID          Case3-138
# First Name       Unknown 2
# Last Name              NaN
# Account Type    Commercial
# Name: 413, dtype: object
# Case ID         Case1-355
# First Name      Unknown 3
# Last Name             NaN
# Account Type      Federal
# Name: 1062, dtype: object
# Case ID         Case2-424
# First Name      Unknown 4
# Last Name             NaN
# Account Type        State
# Name: 1270, dtype: object
# Case ID          Case3-581
# First Name       Unknown 5
# Last Name              NaN
# Account Type    Commercial
# Name: 1742, dtype: object
# Case ID         Case2-610
# First Name      Unknown 6
# Last Name            Bono
# Account Type        State
# Name: 1828, dtype: object
# Case ID         Case2-913
# First Name      Unknown 7
# Last Name             NaN
# Account Type        State
# Name: 2737, dtype: object
# ...

# %%
for row in df2.index.tolist():
    if pd.isna(df2.loc[row,"Case ID"]) == False and pd.isna(df2.loc[row,"Last Name"]) == True:
            df2.loc[row,"Last Name"] = "Unknown %s" % i
            print (df2.loc[row])
# Out:
# Case ID           Case3-70
# First Name       Unknown 1
# Last Name       Unknown 45
# Account Type    Commercial
# Name: 209, dtype: object
# Case ID          Case3-138
# First Name       Unknown 2
# Last Name       Unknown 45
# Account Type    Commercial
# Name: 413, dtype: object
# Case ID          Case1-355
# First Name       Unknown 3
# Last Name       Unknown 45
# Account Type       Federal
# Name: 1062, dtype: object
# Case ID          Case2-424
# First Name       Unknown 4
# Last Name       Unknown 45
# Account Type         State
# Name: 1270, dtype: object
# Case ID          Case3-581
# First Name       Unknown 5
# Last Name       Unknown 45
# Account Type    Commercial
# Name: 1742, dtype: object
# Case ID          Case2-913
# First Name       Unknown 7
# Last Name       Unknown 45
# Account Type         State
# Name: 2737, dtype: object
# Case ID         Case2-1063
# First Name       Unknown 8
# Last Name       Unknown 45
# Account Type         State
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#       Case ID First Name Last Name Account Type
# 18183     NaN        NaN       NaN          NaN
# 18186     NaN        NaN       NaN          NaN
# 18189     NaN        NaN       NaN          NaN
# 18192     NaN        NaN       NaN          NaN
# 18195     NaN        NaN       NaN          NaN
# 18198     NaN        NaN       NaN          NaN
# 18201     NaN        NaN       NaN          NaN
# 18204     NaN        NaN       NaN          NaN
# 18207     NaN        NaN       NaN          NaN

# %%
#drop rows with na
df2 = df2.dropna(axis=0,how="any")
df2[df2.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Case ID, First Name, Last Name, Account Type]
# Index: []

# %%
df2['joined'] = df2.astype(str).values.sum(axis=1)
df2
# Out:
# F:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#           Case ID    First Name   Last Name Account Type  \
# 0         Case1-1          Jack      Dorsey      Federal
# 1         Case2-1          Dave      Cooper        State
# 2         Case3-1         Mudit     AGRAWAL   Commercial
# 3         Case1-2         Larry      Begley      Federal
# 4         Case2-2           Jim    Schraith        State
# 5         Case3-2           Tig      Krekel   Commercial
# 6         Case1-3         Maria      Cirino      Federal
# 7         Case2-3         Blair      Garrou        State
# 8         Case3-3       Stephen      Brooks   Commercial
# ...

# %%
df2['is_duplicated'] = df2.duplicated(['joined'])
df2
# Out:
# Empty DataFrame
# Columns: [Case ID, First Name, Last Name, Account Type, joined, is_duplicated]
# Index: []

# %%
df2 = df2[df2['joined'].duplicated(keep=False)]

a = df2.groupby('joined').apply(lambda x: list(x.index))
print (a)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#splitting the case ids
df2['Case'], df2['Id'] = df2['Case ID'].str.split('-', 1).str
df2
# Out:
# F:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#           Case ID    First Name   Last Name Account Type   Case    Id
# 0         Case1-1          Jack      Dorsey      Federal  Case1     1
# 1         Case2-1          Dave      Cooper        State  Case2     1
# 2         Case3-1         Mudit     AGRAWAL   Commercial  Case3     1
# 3         Case1-2         Larry      Begley      Federal  Case1     2
# 4         Case2-2           Jim    Schraith        State  Case2     2
# 5         Case3-2           Tig      Krekel   Commercial  Case3     2
# 6         Case1-3         Maria      Cirino      Federal  Case1     3
# 7         Case2-3         Blair      Garrou        State  Case2     3
# ...

# %%
for row in df2.index.tolist():
    if df2.loc[row,"Account Type"] == "Federal" and df2.loc[row,"Case"] == "Case1":
        continue
    elif df2.loc[row,"Account Type"] == "State" and df2.loc[row,"Case"] == "Case2":
        continue
    elif df2.loc[row,"Account Type"] == "Commercial" and df2.loc[row,"Case"] == "Case3":
        continue
    else:
        #print (df2.loc[row])
        df3 = df2.drop(df.index[row])
        print (df3)
        continue
# Out:
#           Case ID    First Name   Last Name Account Type   Case    Id
# 0         Case1-1          Jack      Dorsey      Federal  Case1     1
# 1         Case2-1          Dave      Cooper        State  Case2     1
# 2         Case3-1         Mudit     AGRAWAL   Commercial  Case3     1
# 3         Case1-2         Larry      Begley      Federal  Case1     2
# 4         Case2-2           Jim    Schraith        State  Case2     2
# 5         Case3-2           Tig      Krekel   Commercial  Case3     2
# 6         Case1-3         Maria      Cirino      Federal  Case1     3
# 7         Case2-3         Blair      Garrou        State  Case2     3
# 8         Case3-3       Stephen      Brooks   Commercial  Case3     3
# 9         Case1-4          Liam     Donohue      Federal  Case1     4
# 10        Case2-4           Ned        Hill        State  Case2     4
# 11        Case3-4        Victor      Caruso   Commercial  Case3     4
# ...

# %%
# Out:
#            Case ID First Name Last Name Account Type   Case     Id
# count        18239      18239     18239        18239  18239  18239
# unique       18239       4016     11953            3      3   6126
# top     Case2-2954       John     Smith   Commercial  Case3   2721
# freq             1        522        84         6110   6110      3

# %%
df3["First Name"].value_counts(normalize=True)
# Out:
# John            0.028620
# David           0.028456
# Michael         0.024563
# Robert          0.020286
# James           0.016284
# Mark            0.015023
# Thomas          0.012775
# Richard         0.012775
# Peter           0.012501
# William         0.012007
# Paul            0.011020
# Andrew          0.010088
# Daniel          0.008060
# Scott           0.007895
# Stephen         0.007840
# Brian           0.007292
# Charles         0.007018
# Christopher     0.007018
# Kevin           0.007018
# Chris           0.006799
# Steven          0.006579
# Jeffrey         0.006360
# Eric            0.005867
# Jonathan        0.005647
# Joseph          0.005373
# Steve           0.004934
# Tom             0.004770
# George          0.004551
# Patrick         0.004551
# Frank           0.004331
#                   ...
# Tsong-Jen       0.000055
# Noemi           0.000055
# Hilde           0.000055
# Hrach           0.000055
# G?z             0.000055
# Aleksander      0.000055
# ...
